# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
a = np.load('allSignal.npy')

# %%
e = np.load('allError.npy')

# %%
p = np.load('allInputs.npy')

# %%
e
# Out:
# array([[0.00430629],
#        [0.10539786],
#        [0.00753021],
#        [0.00881144],
#        [0.09304029],
#        [0.05219398],
#        [0.04993669],
#        [0.01302805],
#        [0.00766946],
#        [0.0312975 ],
#        [0.03780422],
#        [0.01335919],
#        [0.00644692],
#        [0.00687401],
#        [0.00399621],
#        [0.01454796],
#        [0.00500746],
#        [0.00789615],
#        [0.01256948],
#        [0.04221821],
#        [0.00812816],
#        [0.00498409],
#        [0.00592238],
#        [0.01473345],
#        [0.00846838],
#        [0.01423895],
#        [0.01460172],
#        [0.00406372],
#        [0.01429843],
#        [0.06112405],
#        [0.03469735],
#        [0.00922367],
#        [0.01471793],
#        [0.00759644],
#        [0.01149885],
#        [0.07671786],
#        [0.01379276],
#        [0.00781211],
#        [0.0248604 ],
#        [0.00515053]])

# %%
plt.figure()
plt.scatter(np.arange(len(e)),e)

# %%
plt.figure()
plt.scatter(p[:,0],p[:,1],c=1/e)
plt.colorbar()

# %%
p[goodIdx]
# Out:
# array([[ 6.02545644,  0.49232303],
#        [10.50907887,  0.30442905],
#        [ 5.7       ,  0.59      ],
#        [15.86869367,  0.25672732],
#        [11.43959852,  0.26661239],
#        [14.36332704,  0.22188005],
#        [16.31971095,  0.26909335],
#        [18.92220323,  0.27348369],
#        [ 8.80771372,  0.56222415],
#        [ 9.57886442,  0.59871582],
#        [11.44583115,  0.50420653],
#        [12.06220469,  0.47371181],
#        [10.82354743,  0.56807949],
#        [19.08883524,  0.30269465],
#        [19.59791775,  0.11017989],
#        [16.51741396,  0.40882527],
#        [12.3371983 ,  0.56459178],
#        [18.71528155,  0.38685147],
#        [ 3.98348169,  0.5188353 ],
#        [ 7.77872602,  0.85240995],
#        [14.3626085 ,  0.61805219],
#        [10.72857289,  0.75622932],
#        [ 3.93110481,  0.50392939],
#        [ 2.52487952,  0.78250469],
#        [10.77984226,  0.84043905],
#        [ 9.46268334,  0.96594109],
#        [11.12736129,  0.87805828],
# ...

# %%
goodIdx = np.argsort(e.flatten())

# %%
time = np.linspace(-.5,.5,49997)*1e3

# %%
plt.figure()

plt.plot(time,a[0])
plt.plot(time,a[goodIdx[0]])
#plt.plot(time,a[goodIdx[int(len(e)/2)]])
#plt.plot(time,a[goodIdx[len(e)-1]])
plt.xlim([0,10])
# Out:
# (0.0, 10.0)
